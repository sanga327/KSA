# %% [markdown]
# ## 1. Activation Function
# ### - Step Function Code

# %%
import numpy as np
import matplotlib.pylab as plt

# %%
x = np.array([-1.0, 1.0, 2.0])
y = x > 0
print("x=", x)
print("y=", y)

y = y.astype(np.int64)
print("y=", y)
# Out:
# x= [-1.  1.  2.]
# y= [False  True  True]
# y= [0 1 1]

# %%
# 그래프 그리기
def step_function(x):
    return np.array(x > 0, dtype = np.int64)

x = np.arange(-5.0, 5.0, 0.1)
y = step_function(x)
plt.figure(figsize = (10, 5))
plt.plot(x, y)
plt.ylim(-0.1, 1.1)
plt.show()

# %% [markdown]
# ### - Sigmoid Function

# %%
def sigmoid(x):
    return 1 / (1 + np.exp(-x))

x = np.array([-1, 1.0, 2.0])
y = sigmoid(x)
print("y=", y)

t = np.array([1.0, 2.0, 3.0])
print("t+1=", t+1)
print("1/t=", 1/t)
# Out:
# y= [0.26894142 0.73105858 0.88079708]
# t+1= [2. 3. 4.]
# 1/t= [1.         0.5        0.33333333]

# %%
X = np.arange(-5.0, 5.0, 0.1)
Y = sigmoid(X)
plt.figure(figsize = (10, 5))
plt.plot(X, Y)
plt.ylim(-0.1, 1.1)
plt.show()

# %% [markdown]
# ### - ReLU
# - 입력이 0을 넘으면 그 입력을 그대로 출력하고, 이하이면 0 출력

# %%
def relu(x):
    return np.maximum(0,x)

X = np.arange(-5.0, 5.0, 0.1)
Y = relu(X)
plt.figure(figsize = (10, 5))
plt.plot(X, Y)
plt.ylim(-0.1, 5)
plt.show()

# %% [markdown]
# ## 2. Array

# %%
A = np.array([1,2,3,4])
print("A=", A)
print("A.ndim=", np.ndim(A))
print("A.shape=", A.shape)
# Out:
# A= [1 2 3 4]
# A.ndim= 1
# A.shape= (4,)

# %%
B = np.array([[1,2], [3,4], [5,6]])
print("B=", B)
print("B.ndim=", np.ndim(B))
print("B.shape=", B.shape)
# Out:
# B= [[1 2]
#  [3 4]
#  [5 6]]
# B.ndim= 2
# B.shape= (3, 2)

# %% [markdown]
# ### - 행렬의 내적(행렬곱)

# %%
A = np.array([[1,2], [3,4]])
B = np.array([[5,6], [7,80]])
print("A.shape=", A.shape)
print("B.shape=", B.shape)
# Out:
# A.shape= (2, 2)
# B.shape= (2, 2)

# %%
result = np.dot(A, B)
print("A.B=", result)
print("result.shape=", result.shape)
# Out:
# A.B= [[ 19 166]
#  [ 43 338]]
# result.shape= (2, 2)

# %%
A = np.array([[1,2,3], [4,5,6]])
B = np.array([[1,2], [3,4], [5,6]])
print("A.shape=", A.shape)
print("B.shape=", B.shape)
# Out:
# A.shape= (2, 3)
# B.shape= (3, 2)

# %%
result = np.dot(A, B)
print("A.B=", result)
print("result.shape=", result.shape)
# Out:
# A.B= [[22 28]
#  [49 64]]
# result.shape= (2, 2)

# %%
A = np.array([[1,2], [3,4], [5,6]])
print("A.shape=", A.shape)
B = np.array([7,8])
print("B.shape=", B.shape)
print("A.B=", np.dot(A,B))
# Out:
# A.shape= (3, 2)
# B.shape= (2,)
# A.B= [23 53 83]

# %% [markdown]
# ### - 신경망의 내적 Code

# %%
x = np.array([1,2])
print("shape of input=", x.shape)
weight = np.array([[1,3,5], [2,4,6]])
print("weight=", weight)
print("shape of weight=", weight.shape)
y = np.dot(x, weight)
print("y=", y)
# Out:
# shape of input= (2,)
# weight= [[1 3 5]
#  [2 4 6]]
# shape of weight= (2, 3)
# y= [ 5 11 17]

# %% [markdown]
# ## 3. 신경망 구현하기

# %%
# 각 층별 신호 전달 구현
x = np.array([1.0, 0.5])
weight1 = np.array([[0.1, 0.3, 0.5], [0.2, 0.4, 0.6]])
bias1 = np.array([0.1, 0.2, 0.3])
print("shape of input=", x.shape)
print("shape of weight1=", weight1.shape)  
print("shape of bias1=", bias1.shape)
# Out:
# shape of input= (2,)
# shape of weight1= (2, 3)
# shape of bias1= (3,)

# %%
# 활성화 함수 처리
result_of_inner1 = np.dot(x, weight1) + bias1
result_of_sigmoid1 = sigmoid(result_of_inner1)
print("result of inner1=", result_of_inner1)  # a
print("result of sigmoid1=", result_of_sigmoid1)  # z
# Out:
# result of inner1= [0.3 0.7 1.1]
# result of sigmoid1= [0.57444252 0.66818777 0.75026011]

# %% [markdown]
# ### - 각 층별 신호 전달 구현: 2층으로

# %%
weight2 = np.array([[0.1, 0.4], [0.2, 0.5], [0.3, 0.6]])
bias2 = np.array([0.1, 0.2])
print("shape of sigmoid1=", result_of_sigmoid1.shape)
print("shape of weight2=", weight2.shape)
print("shape of bias2=", bias2.shape)
# Out:
# shape of sigmoid1= (3,)
# shape of weight2= (3, 2)
# shape of bias2= (2,)

# %%
result_of_inner2 = np.dot(result_of_sigmoid1, weight2) + bias2
result_of_sigmoid2 = sigmoid(result_of_inner2)
print("result of inner2=", result_of_inner2)
print("result of sigmoid2=", result_of_sigmoid2)
# Out:
# result of inner2= [0.51615984 1.21402696]
# result of sigmoid2= [0.62624937 0.7710107 ]

# %% [markdown]
# ### - 각 층별 신호 전달 구현: 출력층 구현

# %%
def identity_function(x):
    return x

weight3 = np.array([[0.1, 0.3], [0.2, 0.4]])
bias3 = np.array([0.1, 0.2])
print("shape of sigmoid2=", result_of_sigmoid2.shape)
print("shape of weight3=", weight3.shape)
print("shape of bias3=", bias3.shape)
# Out:
# shape of sigmoid2= (2,)
# shape of weight3= (2, 2)
# shape of bias3= (2,)

# %%
result_of_inner3 = np.dot(result_of_sigmoid2, weight3) + bias3
output = identity_function(result_of_inner3)
print("output=", output)
# Out:
# output= [0.31682708 0.69627909]

# %% [markdown]
# ### - 구현 정리
# - 은닉층이 2개인 신경망
# - init_network(): 가중치와 편향을 초기화 후 network에 저장
# - forward(): 입력을 출력으로 변환하는 처리 과정

# %%
def init_network():
    network={}
    network["weight1"] = np.array([[0.1, 0.3, 0.5], [0.2, 0.4, 0.6]])
    network["bias1"] = np.array([0.1, 0.2, 0.3])
    network["weight2"] = np.array([[0.1, 0.4], [0.2, 0.5], [0.3, 0.6]])
    network["bias2"] = np.array([0.1, 0.2])
    network["weight3"] = np.array([[0.1, 0.3], [0.3, 0.6]])
    network["bias3"] = np.array([0.1, 0.2])
    
    return network

# %%
def forward(network, x):
    weight1, weight2, weight3 = network["weight1"], network["weight2"], network["weight3"]
    bias1, bias2, bias3 = network["bias1"], network["bias2"], network["bias3"]
    
    result_of_inner1 = np.dot(x, weight1) + bias1
    output1 = sigmoid(result_of_inner1)

    result_of_inner2 = np.dot(output1, weight2) + bias2
    output2 = sigmoid(result_of_inner2)

    result_of_inner1 = np.dot(output2, weight3) + bias3
    y = identity_function(result_of_inner3)
    
    return y

# %%
network = init_network()
x = np.array([1.0, 0.5])
y = forward(network, x)
print(y)
# Out:
# [0.31682708 0.69627909]

# %% [markdown]
# ## 4. 출력층 구현하기

# %% [markdown]
# ### - 항등 함수와 소프트맥스 함수

# %% [markdown]
# - 오류 발생 코드

# %%
def softmax(matrix):
    exponential_matrix = np.exp(matrix)
    sum_of_exponential_matrix = np.sum(exponential_matrix)
    y = exponential_matrix / sum_of_exponential_matrix

# %%
matrix = np.array([1010, 1000, 900])
result_of_softmax = np.exp(matrix) / np.sum(np.exp(matrix))
print(result_of_softmax)
# Out:
# [nan nan nan]
# C:\Users\user\anaconda3\envs\ksa_study\lib\site-packages\ipykernel_launcher.py:2: RuntimeWarning: overflow encountered in exp
#
# C:\Users\user\anaconda3\envs\ksa_study\lib\site-packages\ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in true_divide

# %% [markdown]
# - 지수함수에 큰 값이 들어가 overflow가 발생한다.
# - 제대로 softmax가 계산되지 않는다.

# %%
maximum_of_matrix = np.max(matrix)
difference_from_maximum = matrix - maximum_of_matrix
print(difference_from_maximum)
# Out:
# [   0  -10 -110]

# %%
result_of_softmax = np.exp(difference_from_maximum) / np.sum(np.exp(difference_from_maximum))
print(result_of_softmax)
# Out:
# [9.99954602e-01 4.53978687e-05 1.68883521e-48]

# %% [markdown]
# - 수정된 코드

# %%
def softmax(matrix):
    maximum_of_matrix = np.max(matrix)
    difference_from_maximum = matrix - maximum_of_matrix
    exponential_of_difference = np.exp(difference_from_maximum)
    sum_of_exponential = np.sum(exponential_of_difference)
    y = exponential_of_difference / sum_of_exponential
    
    return y

# %%
matrix = np.array([0.3, 2.9, 4.0])
y = softmax(matrix)
print("y=", y)
print("sum of y=", np.sum(y))
# Out:
# y= [0.01821127 0.24519181 0.73659691]
# sum of y= 1.0
